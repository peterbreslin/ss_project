# %% [markdown]
# # Looking at the SEP file

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading in the txt file
sp = 'C:/Users/Peter/py_projects/solar_stats/SEP.txt'
f = open(sp, 'r')
print(f.read())
# Out:
# Prepared by the U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center
#
#
#                       Solar Proton Events Affecting the Earth Environment
#
#                                January 1976 - March 2011
# ...
# -------------PARTICLE EVENT----------     ASSOCIATED  ---------FLARE AND ACTIVE REGION----------
#  Start            Maximum    Proton Flux      CME       Flare Max.  Importance  Location Region#
# (Day/UT)                   (pfu @ >10 MeV)            (Loc./ Day UT)(Xray/Opt.)           (SWO)
# ------------------------------------------------------------------------------------------------
#
#                 1976
# Apr 30/2120      May 01/1700      12                    Apr 30/2114   X2/2B       S09W47    700
#
#                 1977
# Sep 19/1430      Sep 19/2130     200                    Sep 19/1054   X2/3B       N08W58    889
# Nov 22/1400      Nov 22/1800     160                    Nov 22/1006   X1/2N       N24W38    939
#
#                 1978
# ...

# %% [markdown]
# ### Making a dataframe of the data from (1996-08-01 12:36:35) onwards

# %%
col1='year'
col2='start'
col3='event_max'
col4='proton_flux'
col5='associated_cme'
col6='flare_max'
col7='importance'
col8='location'
col9='region'

# %%
years = ['1997', '1997',
         '1998', '1998', '1998', '1998', '1998', '1998', '1998', '1998',
         '1999', '1999', '1999', '1999', '1999',
         '2000', '2000', '2000', '2000', '2000', '2000', '2000', '2000', '2000', '2000', '2000', '2000', '2000',
         '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001', '2001',
         '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002', '2002',
         '2003', '2003', '2003', '2003', '2003', '2003', '2003', '2003', '2003',
         '2004', '2004', '2004', '2004', '2004', '2004',
         '2005', '2005', '2005', '2005', '2005', '2005', '2005',
         '2006', '2006',
         '2010',
         '2011', '2011', '2011', '2011', '2011', '2011', '2011',
         '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012',
         '2013', '2013', '2013', '2013', '2013', '2013', '2013',
         '2014', '2014', '2014', '2014',
         '2015', '2015',
         '2016',
         '2017' ]

# %%
start = ['Nov 04/0830', 'Nov 06/1305',
        'Apr 20/1400', 'May 02/1420', 'May 06/0845', 'Aug 24/2355', 'Sep 25/0010', 'Sep 30/1520', 'Nov 08/0245', 'Nov 14/0810',
        'Jan 23/1105', 'Apr 24/1804', 'May 05/1820', 'Jun 02/0245', 'Jun 04/0925',
        'Feb 18/1130', 'Apr 04/2055', 'Jun 07/1335', 'Jun 10/1805', 'Jul 14/1045', 'Jul 22/1320', 'Jul 28/1050', 'Aug 11/1650', 'Sep 12/1555', 'Oct 16/1125', 'Oct 26/0040', 'Nov 08/2350', 'Nov 24/1520',
        'Jan 28/2025', 'Mar 29/1635', 'Apr 02/2340', 'Apr 10/0850', 'Apr 15/1410', 'Apr 18/0315', 'Apr 28/0430', 'May 07/1915', 'Jun 15/1750', 'Aug 10/1020', 'Aug 16/0135', 'Sep 15/1435', 'Sep 24/1215', 'Oct 01/1145', 'Oct 19/2225', 'Oct 22/1910', 'Nov 04/1705', 'Nov 19/1230', 'Nov 22/2320', 'Dec 26/0605', 'Dec 29/0510', 'Dec 30/0245',
            'Jan 11/0530', 'Jan 15/2000', 'Feb 20/0755',' Mar 17/0850', 'Mar 19/0650', 'Mar 20/1525', 'Mar 23/1320', 'Apr 17/1540', 'Apr 21/2320', 'May 23/1055', 'Jul 07/1955', 'Jul 17/1600', 'Jul 19/1515', 'Jul 23/1025', 'Aug 14/1620', 'Aug 22/0940', 'Aug 24/0835', 'Sep 07/1650', 'Nov 10/0540',
            'May 29/1530', 'May 31/0645', 'Jun 19/0450', 'Oct 26/2235', 'Oct 29/0615', 'Nov 03/0815', 'Nov 05/0600', 'Nov 22/0230', 'Dec 02/1730', 
            'Apr 11/1845', 'Jul 26/2250', 'Sep 14/0005', 'Sep 20/0100', 'Nov 01/0805', 'Nov 08/0115', 
            'Jan 17/1750', 'May 15/0240', 'Jun 17/0500', 'Jul 15/0345', 'Jul 29/1715', 'Aug 23/1045', 'Sep 11/0425', 
            'Dec 07/1930', 'Dec 13/0925', 
            'Aug 14/1245',
            'Mar 08/0800', 'Mar 22/0135', 'Jun 07/1820', 'Aug 05/2150', 'Aug 09/1210', 'Sep 26/1155', 'Nov 27/0125', 
            'Jan 24/1530', 'Jan 28/0205', 'Mar 08/1115', 'Mar 13/2045', 'May 17/0430', 'May 27/1045', 'Jun 16/2020', 'Jul 07/0745', 'Jul 12/2225', 'Jul 18/0600', 'Jul 23/2145', 'Sep 02/0859', 'Sep 28/0445', 
            'Mar 17/0700', 'Apr 11/1645', 'May 17/1720', 'May 23/0650', 'Jun 24/0520', 'Sep 30/2005', 'Dec 28/2315', 
            'Jan 06/1600', 'Jan 09/0340', 'Feb 20/0925', 'Feb 28/0845', 
            'Jun 18/1445', 'Oct 29/1000', 
            'Jan 02/0450',
            'Sep 05/1930']

# %%
proton_flux = [72, 490, 
               1700, 150, 210, 670, 44, 1200, 11, 310, 
               14, 32, 14, 48, 64,
               13, 55, 84, 46, 24000, 17, 18, 17, 320, 15, 15, 14800, 940,
               49, 35, 1110, 355, 951, 321, 57, 30, 26, 17, 493, 11, 12900, 2360, 11, 24, 31700, 34, 18900, 779, 76, 108,
               91, 15, 13, 13, 53, 19, 16, 24, 2520, 820, 22, 234, 13, 28, 26, 36, 317, 208, 404,
               121, 27, 24, 466, 29500, 1570, 353, 13, 86,
               35, 2086, 273, 57, 63, 495,
               5040, 3140, 44, 134, 41, 330, 1880,
               1980, 698,
               14,
               50, 14, 72, 96, 26, 35, 80,
               6310, 796, 6530, 469, 255, 14, 14, 25, 96, 136, 12, 59, 28,
               16, 114, 41, 1660, 14, 182, 29,
               42, 1033, 22, 103,
               16, 23,
               21,
               210]

# %%
associated_cme = ['W/04 0610', 'W/06 1300',
                 'W/20 1007', 'Halo/02 1406', 'W/06 0829', np.nan, np.nan, np.nan, np.nan, np.nan,
                 np.nan, 'Halo/24 1331', 'Halo/03 0606', 'Halo/01 1937', 'NW/ 04 0726', 
                 'W/18 0954', 'W/04 1632', 'Halo/06 1554', 'Halo/10 1708', 'Halo/14 1054', 'NW/22 1230', np.nan, np.nan, 'Halo/12 1331', 'Halo/16 0727', 'Halo/25 0826', 'Halo/08 2306', 'Halo/24 0530', 
            'Jan 08/2025', 'Jan 14/0627', 'Feb 20/0612', 'Mar 15/2310', np.nan, 'Mar 18/0231', 'Mar 22/1114', 'Apr 17/0824', 'Apr 21/0151', 'May 22/0354', 'Jul 07/1143', 'Jul 15/2008', np.nan, 'Jul 20/2130', 'Aug 14/0212', 'Aug 22/0157', 'Aug 24/0112', 'Sep 05/1706', 'Nov 09/1323', 
            'May 28/0027', 'May 31/0224', 'Jun 17/2255', 'Oct 26/1819', 'Oct 28/1110', np.nan, 'Nov 04/1929', 'Nov 20/2353', 'Dec 02/0948', 
            'Apr 11/0419', 'Jul 25/1514', 'Sep 12/0056', 'Sep 19/1712', np.nan, 'Nov 07/1606', 
            'Jan 15/2302', 'May 13/1657', 'Jun 16/2022', 'Jul 13/1449', 'Jul 27/0502', 'Aug 22/1727', 'Sep 07/1740', 
            'Dec 05/1035', 'Dec 13/0240', 
            'Aug 14/1005',
            'Mar 07/2012', np.nan, 'Jun 07/0803', 'Aug 04/0412', 'Aug 09/0805', 'Sep 22/1101', 'Nov 26/0710', 
            'Jan 23/0359', 'Jan 27/1837', 'Mar 07/0024', 'Mar 13/1741', 'May 17/0147', np.nan, 'Jun 14/1435', 'Jul 06/2308', 'Jul 12/1710', 'Jul 17/1715', np.nan, 'Aug 31/2043', 'Sep 27/2357', 
            'Mar 15/0658', 'Apr 11/0716', 'May 15/0148', 'May 22/1322', 'Jun 21/0314', 'Sep 29/2337', 'Dec 28/1802', 
            np.nan, 'Jan 07/1832', 'Feb 20/0756', 'Feb 25/0049', 
            'Jun 18/0127', np.nan, 
            'Jan 02/0011',
            'Sep 04/2033']

# %%
importance = ['X2/2B', 'X9/2B',
             'M1/EPL', 'X1/3B', 'X2/1N', 'X1/3B', 'M7/3B', 'M2/2N', np.nan, 'C1/BSL', 
             'M5', np.nan, 'M4/2N', np.nan, 'M3/2B', 
             'M1/2N', 'C9/2F', 'X2/3B', 'M5/3B', 'X5/3B', 'M3/2N', np.nan, np.nan, 'M1/2N', 'M2', 'C4', 'M7/multiple', 'X2/3B', 
             'M1/1N', 'X1/1N', 'X20', 'X2/3B', 'X14/2B', 'C2', 'M7/2B', np.nan, np.nan, 'C3', np.nan, 'M1/1N', 'X2/2B', 'M9', 'X1/2B', 'X1/2B', 'X1/3B', 'M2/1N', 'M9/2N', 'M7/1B', 'X3', np.nan,
             'C9', 'M4', 'M5/1N','M2/1F', np.nan, 'M1', 'M1', 'M2/2N', 'X1/1F', 'C5/DSF', 'M1', 'X3/3B', np.nan, 'X3', 'M2/1N', 'M5/2B', 'X3/1F', 'C5/DSF', 'M4/2B',
             'X3/2B', 'M9/2B', 'M6', 'X1/1N', 'X17/4B', np.nan, 'X28/3B', 'M5/2B', 'C7', 
             'C9/1F', 'M1/1F', 'M4/2N', 'M1', np.nan, 'X2',
             'X2', 'M8/2B', 'M4', 'M5', 'M3', 'M5/1N', 'X17/3B', 
             'X9/2N', 'X3/4B', 
             'C4/0F',
             'M3/SF', np.nan, 'M2/2N', 'M9/2B', 'X6/2B', 'X1/2N', np.nan, 
             'M8/2B', 'X1/1F', 'X5/3B', 'M7', 'M5/1F', np.nan, 'M1/1N', 'X1', 'X1/2B', 'M1', np.nan, 'C8/2F', 'C3/1F', 
             'M1/1F', 'M6/3B', 'X1/2N', 'M5/3N', 'M2/1F', np.nan, 'C9/SN', 
             np.nan, 'X1/2N', 'M3/SN', 'X4/2B', 
             'M1.3', np.nan,
             'M2.0',
             'M5.0']

# %%
location = ['S14W33', 'S18W63',
           'S43W90', 'S15W15', 'S11W65', 'N30E07', 'N18E09', 'N23W81', np.nan, 'N28W90', 
           'N27E90', 'NW limb', 'N15E32', np.nan, 'N17W69', 
           'S29E07', 'N16W66', 'N20E18', 'N22W38', 'N22W07', 'N14W56', np.nan, np.nan, 'S17W09', 'N04W90', 'N00W90','N00-10W75-80', 'N20W05', 
           'S04W59', 'N14W12', 'N18W82', 'S23W09', 'S20W85', 'S20W limb', 'N17W31', 'NW limb', 'W limb', 'Disk center', 'Far Backside', 'S21W49', 'S16E23', 'S22W91', 'N15W29', 'S18E16', 'N06W18', 'S13E42', 'S15W34', 'N08W54', 'S26E90', np.nan,
           'E limb', 'W limb', 'N12W72', 'S08W03', np.nan, 'S09W46', 'W limb', 'S14W34', 'S14W84', 'S19W56', 'W limb', 'N19W01', np.nan, 'SE limb', 'N09W54', 'S07W62', 'S08W90', 'N09E28', 'S12W29', 
           'S07W17', 'S07W65', 'S08E61', 'N02W38', 'S16E08', np.nan, 'S19W83', 'N02W17', 'W limb',
           'S14W47', 'N08W33', 'N04E42', 'N03W58', 'Backside', 'N09W17', 
           'N15W05', 'N12E11', 'N09W87', 'N10W80', 'N11E90', 'S12W60', 'S06E89', 
           'S07E79', 'S05W23', 
           'N17W52',
           'N24W59', np.nan, 'S21W64', 'N15W49', 'N17W83', 'N11E74', 'N08W49', 
           'N28W36', 'N27W71', 'N17E15', 'N18W62', 'N12W89',  np.nan, 'S17E14', 'S18W50', 'S16W09', 'S17W75', 'S16W86', 'S06E20', 'N08W41', 
           'N11E12', 'N09E12', 'N11E51', 'N15W70', 'S16E66', 'N15W40', 'S18E07', 
           'S15E90', 'S15W11', 'S15W67', 'S12E82', 
           'S13W102', np.nan, 
           'S21W73',
           'S08W16']

# %%
region = [8100, 8100,
         8194, 8210, 8210, 8307, 8340, 8340, np.nan, 8375,
         np.nan, 8517, 8525, np.nan, 8552,
         8872, 8933, 9026, 9026, 9077, 9085, np.nan, np.nan, 'Filament', 9182, np.nan, '9212,13,18', 9236, 
         9313, 9393, 9393, 9415, 9415, 9415, 9433, np.nan, np.nan, np.nan, np.nan, 9608, 9632, 9628, 9661, 9672, 9684, 9704, 9704, 9742, 9767, np.nan,
         np.nan, np.nan, 9825, 9866, np.nan, 9866, 9866, 9906, 9906, np.nan, 17, 30, np.nan, 39, 61, 69, 69, 102, 180,
         365, 365, 386, 484, 486, np.nan, 486, 501, np.nan, 
         588, 652, 672, 672, np.nan, 696, 
         720, 759, 775, 786, 792, 798, 808, 
         930, 930, 
         1099, 
         1164, 1169, 1226, 1261, 1263, 1302, 1353, 
         1402, 1402, 1429, 1429, 1476, 1482, 1504, 1515, 1520, 1520, 1520, np.nan, 1577,
         1692, 1719, 1748, 1745, 1777, np.nan, 1936, 
         1936, 1944, 1976, 1990, 
         2365, 2434, 
         2473, 
         2673]

# %%
data = {col1: years,
        col2: start,
        col3: event_max,
        col4: proton_flux,
        col5: associated_cme,
        col6: flare_max,
        col7: importance,
        col8: location,
        col9: region}

# %%
sep = pd.DataFrame(data, columns = [col1,col2,col3,col4,col5,col6,col7,col8,col9])

# %%
custom_df = 'C:/Users/Peter/py_projects/solar_stats/custom_df.p'
df = pd.read_pickle(custom_df)

# %%
# Need to convert each column to the wanted datatype
test = sep.copy()

# %%
# dates and times
from datetime import datetime as dt

# %%
df.cme_time.dtype
# Out:
# dtype('<M8[ns]')

# %%
x = test.start.iloc[1]
x
# Out:
# 'Nov 06/1305'

# %%
my_date = dt.strptime(x, "%b %d/%H%M")
my_date
# Out:
# datetime.datetime(1900, 11, 6, 13, 5)

# %%
# Going to combine the year column with the other date columns
print(sep.year.isnull().sum())
print(sep.start.isnull().sum())
print(sep.event_max.isnull().sum())
print(sep.flare_max.isnull().sum())
# Out:
# 0
# 0
# 0
# 17

# %%
# start dates
test['start'] = test.year.astype(str) + ' ' + test.start

# %%
# Entry 59 had May 1775 inputted in the start column
test
# Out:
#      year             start    event_max  proton_flux associated_cme  \
# 0    1997  1997 Nov 04/0830  Nov 04/1120           72      W/04 0610
# 1    1997  1997 Nov 06/1305  Nov 07/0255          490      W/06 1300
# 2    1998  1998 Apr 20/1400  Apr 21/1205         1700      W/20 1007
# 3    1998  1998 May 02/1420  May 02/1650          150   Halo/02 1406
# 4    1998  1998 May 06/0845  May 06/0945          210      W/06 0829
# ..    ...               ...          ...          ...            ...
# 124  2014  2014 Feb 25/1355  Feb 28/0845          103     SE/25 0130
# 125  2015  2015 Jun 18/1135  Jun 18/1445           16     SW/18 0125
# 126  2015  2015 Oct 29/0550  Oct 29/1000           23     SW/29 0236
# 127  2016  2016 Jan 02/0430  Jan 02/0450           21     SW/02 2324
# 128  2017  2017 Sep 05/0751  Sep 05/1930          210     SW/04 2048
#
#        flare_max importance location region
# 0    Nov 04/0558      X2/2B   S14W33   8100
# 1    Nov 06/1155      X9/2B   S18W63   8100
# ...

# %%
start_dates = np.zeros(len(test.start))
start_dates = start_dates.astype('O')

# %%
for i in range(len(start_dates)):
    #start_dates[i] = dt.strptime(test.start.iloc[i], "%Y %b %d/%H%M")
    start_dates[i] = pd.to_datetime(test.start.iloc[i], format="%Y %b %d/%H%M", errors='ignore')

# %%
test['start_dates'] = start_dates

# %%
pd.set_option('display.max_rows', 10)
test
# Out:
#      year             start    event_max  proton_flux associated_cme  \
# 0    1997  1997 Nov 04/0830  Nov 04/1120           72      W/04 0610
# 1    1997  1997 Nov 06/1305  Nov 07/0255          490      W/06 1300
# 2    1998  1998 Apr 20/1400  Apr 21/1205         1700      W/20 1007
# 3    1998  1998 May 02/1420  May 02/1650          150   Halo/02 1406
# 4    1998  1998 May 06/0845  May 06/0945          210      W/06 0829
# ..    ...               ...          ...          ...            ...
# 124  2014  2014 Feb 25/1355  Feb 28/0845          103     SE/25 0130
# 125  2015  2015 Jun 18/1135  Jun 18/1445           16     SW/18 0125
# 126  2015  2015 Oct 29/0550  Oct 29/1000           23     SW/29 0236
# 127  2016  2016 Jan 02/0430  Jan 02/0450           21     SW/02 2324
# 128  2017  2017 Sep 05/0751  Sep 05/1930          210     SW/04 2048
#
#        flare_max importance location region         start_dates
# 0    Nov 04/0558      X2/2B   S14W33   8100 1997-11-04 08:30:00
# ...

# %%
# event max dates
test['event_max'] = test.year.astype(str) + ' ' + test.event_max

# %%
test
# Out:
#      year             start         event_max  proton_flux associated_cme  \
# 0    1997  1997 Nov 04/0830  1997 Nov 04/1120           72      W/04 0610
# 1    1997  1997 Nov 06/1305  1997 Nov 07/0255          490      W/06 1300
# 2    1998  1998 Apr 20/1400  1998 Apr 21/1205         1700      W/20 1007
# 3    1998  1998 May 02/1420  1998 May 02/1650          150   Halo/02 1406
# 4    1998  1998 May 06/0845  1998 May 06/0945          210      W/06 0829
# ..    ...               ...               ...          ...            ...
# 124  2014  2014 Feb 25/1355  2014 Feb 28/0845          103     SE/25 0130
# 125  2015  2015 Jun 18/1135  2015 Jun 18/1445           16     SW/18 0125
# 126  2015  2015 Oct 29/0550  2015 Oct 29/1000           23     SW/29 0236
# 127  2016  2016 Jan 02/0430  2016 Jan 02/0450           21     SW/02 2324
# 128  2017  2017 Sep 05/0751  2017 Sep 05/1930          210     SW/04 2048
#
#        flare_max importance location region         start_dates
# ...

# %%
event_dates = np.zeros(len(test.event_max))
event_dates = event_dates.astype('O')
for i in range(len(event_dates)):
    event_dates[i] = pd.to_datetime(test.event_max.iloc[i], format="%Y %b %d/%H%M", errors='ignore')

# %%
test['event_dates'] = event_dates

# %%
test
# Out:
#      year             start         event_max  proton_flux associated_cme  \
# 0    1997  1997 Nov 04/0830  1997 Nov 04/1120           72      W/04 0610
# 1    1997  1997 Nov 06/1305  1997 Nov 07/0255          490      W/06 1300
# 2    1998  1998 Apr 20/1400  1998 Apr 21/1205         1700      W/20 1007
# 3    1998  1998 May 02/1420  1998 May 02/1650          150   Halo/02 1406
# 4    1998  1998 May 06/0845  1998 May 06/0945          210      W/06 0829
# ..    ...               ...               ...          ...            ...
# 124  2014  2014 Feb 25/1355  2014 Feb 28/0845          103     SE/25 0130
# 125  2015  2015 Jun 18/1135  2015 Jun 18/1445           16     SW/18 0125
# 126  2015  2015 Oct 29/0550  2015 Oct 29/1000           23     SW/29 0236
# 127  2016  2016 Jan 02/0430  2016 Jan 02/0450           21     SW/02 2324
# 128  2017  2017 Sep 05/0751  2017 Sep 05/1930          210     SW/04 2048
#
#        flare_max importance location region         start_dates  \
# ...

# %%
# flare max dates ---> there are some nans here
sep.flare_max.isnull().sum()
# Out:
# 17

# %%
test['flare_max'] = test.year.astype(str) + ' ' + test.flare_max

# %%
flare_dates = np.zeros(len(test.flare_max))
flare_dates = flare_dates.astype('O')

# %%
for i in range(len(flare_dates)):
    flare_dates[i] = pd.to_datetime(test.flare_max.iloc[i], format="%Y %b %d/%H%M", errors='ignore')

# %%
test['flare_dates'] = flare_dates

# %%
# proton flux to float
test.proton_flux = test.proton_flux.astype(float)

# %%
# making a new df
data2 = {col1: years,
        col2: start_dates,
        col3: event_dates,
        col4: proton_flux,
        col5: associated_cme,
        col6: flare_dates,
        col7: importance,
        col8: location,
        col9: region}

# %%
sep2 = pd.DataFrame(data2, columns = [col1,col2,col3,col4,col5,col6,col7,col8,col9])

# %%
sep2
# Out:
#      year               start           event_max  proton_flux associated_cme  \
# 0    1997 1997-11-04 08:30:00 1997-11-04 11:20:00           72      W/04 0610
# 1    1997 1997-11-06 13:05:00 1997-11-07 02:55:00          490      W/06 1300
# 2    1998 1998-04-20 14:00:00 1998-04-21 12:05:00         1700      W/20 1007
# 3    1998 1998-05-02 14:20:00 1998-05-02 16:50:00          150   Halo/02 1406
# 4    1998 1998-05-06 08:45:00 1998-05-06 09:45:00          210      W/06 0829
# ..    ...                 ...                 ...          ...            ...
# 124  2014 2014-02-25 13:55:00 2014-02-28 08:45:00          103     SE/25 0130
# 125  2015 2015-06-18 11:35:00 2015-06-18 14:45:00           16     SW/18 0125
# 126  2015 2015-10-29 05:50:00 2015-10-29 10:00:00           23     SW/29 0236
# 127  2016 2016-01-02 04:30:00 2016-01-02 04:50:00           21     SW/02 2324
# 128  2017 2017-09-05 07:51:00 2017-09-05 19:30:00          210     SW/04 2048
#
# ...

# %%
# saving to a df
sep2.to_pickle('custom_sep.p')

# %%
# Testing the save
df2 = 'C:/Users/Peter/py_projects/solar_stats/custom_sep.p'
t3 = pd.read_pickle(df2)
t3
# Out:
#      year               start           event_max  proton_flux associated_cme  \
# 0    1997 1997-11-04 08:30:00 1997-11-04 11:20:00           72      W/04 0610
# 1    1997 1997-11-06 13:05:00 1997-11-07 02:55:00          490      W/06 1300
# 2    1998 1998-04-20 14:00:00 1998-04-21 12:05:00         1700      W/20 1007
# 3    1998 1998-05-02 14:20:00 1998-05-02 16:50:00          150   Halo/02 1406
# 4    1998 1998-05-06 08:45:00 1998-05-06 09:45:00          210      W/06 0829
# ..    ...                 ...                 ...          ...            ...
# 124  2014 2014-02-25 13:55:00 2014-02-28 08:45:00          103     SE/25 0130
# 125  2015 2015-06-18 11:35:00 2015-06-18 14:45:00           16     SW/18 0125
# 126  2015 2015-10-29 05:50:00 2015-10-29 10:00:00           23     SW/29 0236
# 127  2016 2016-01-02 04:30:00 2016-01-02 04:50:00           21     SW/02 2324
# 128  2017 2017-09-05 07:51:00 2017-09-05 19:30:00          210     SW/04 2048
#
# ...
