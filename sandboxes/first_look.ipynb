# %% [markdown]
# ## Importing the DataFrame

# %%
# Packages
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Defining the path for the dataframe
dataframe = 'C:/Users/Peter/py_projects/solar_stats/cdaw_cme_flare_ar_smart_database.p'

# Using PICKLE to import the dataframe
infile = open(dataframe, 'rb')
df_pickle = pickle.load(infile)
infile.close()

# Can import the dataframe using PANDAS also --> simpler?
df = pd.read_pickle(dataframe)

# Looking at the header
df.head()
# Out:
#              cme_time  cme_angle  cme_width  cme_speed  initial_2nd_order  \
# 0 1996-08-01 12:36:35      274.0       35.0      499.0              451.0
# 1 1996-08-01 18:12:21      210.0       82.0      118.0               94.0
# 2 1996-08-03 19:45:37      231.0       26.0       71.0               59.0
# 3 1996-08-07 13:15:05      242.0       27.0        NaN                NaN
# 4 1996-08-10 09:25:05       68.0       68.0      148.0              133.0
#
#    final_2nd_order  20r_2nd_order  cme_acceleration cme_mass  \
# 0            551.0          615.0               7.4  2.6e+14
# 1            142.0          324.0               4.0  9.8e+13
# 2             84.0          128.0               0.5      NaN
# 3              NaN            NaN               NaN      NaN
# 4            164.0          201.0               1.0  4.6e+14
#
#   cme_kinetic_energy  ...  smart_positive_area smart_psl_length smart_r_value  \
# 0            3.2e+29  ...                  NaN              NaN           NaN
# 1            6.8e+27  ...                  NaN              NaN           NaN
# 2                NaN  ...                  NaN              NaN           NaN
# 3                NaN  ...                  NaN              NaN           NaN
# 4            5.0e+28  ...                  NaN              NaN           NaN
#
#   smart_b_max smart_b_min smart_observation_time smart_string_latlon  \
# 0         NaN         NaN                    NaT                 NaN
# 1         NaN         NaN                    NaT                 NaN
# 2         NaN         NaN                    NaT                 NaN
# 3         NaN         NaN                    NaT                 NaN
# 4         NaN         NaN                    NaT                 NaN
#
#   smart_total_area smart_negative_area smart_hg_longitude
# 0              NaN                 NaN                NaN
# 1              NaN                 NaN                NaN
# 2              NaN                 NaN                NaN
# 3              NaN                 NaN                NaN
# 4              NaN                 NaN                NaN
#
# [5 rows x 59 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30228, step=1)

# %%
df.columns
# Out:
# Index(['cme_time', 'cme_angle', 'cme_width', 'cme_speed', 'initial_2nd_order',
#        'final_2nd_order', '20r_2nd_order', 'cme_acceleration', 'cme_mass',
#        'cme_kinetic_energy', 'cme_mpa', 'cme_remarks', 'cme_quality',
#        'cme_halo', 'flare_end_time', 'flare_hg_longitude', 'flare_window_end',
#        'flare_hcx_position', 'flare_active_region_no', 'flare_window_start',
#        'flare_string_latlon', 'flare_start_time', 'flare_peak_time',
#        'flare_type', 'flare_hcy_position', 'flare_hg_latitude',
#        'flare_goes_class', 'srs_lon_extent', 'srs_no_spots',
#        'srs_carrington_lon', 'srs_active_region_no', 'srs_observation_time',
#        'srs_hg_latitude', 'srs_mcintosh', 'srs_area', 'srs_hale',
#        'srs_hg_longitude', 'srs_string_latlon', 'smart_hcx_position',
#        'smart_flux_fraction', 'smart_limb_event', 'smart_hcy_position',
#        'smart_positive_flux', 'smart_bipole_separation', 'smart_negative_flux',
#        'smart_b_mean', 'smart_wlsg', 'smart_total_flux', 'smart_hg_latitude',
#        'smart_positive_area', 'smart_psl_length', 'smart_r_value',
#        'smart_b_max', 'smart_b_min', 'smart_observation_time',
#        'smart_string_latlon', 'smart_total_area', 'smart_negative_area',
#        'smart_hg_longitude'],
#       dtype='object')

# %%
df.dtypes
# Out:
# cme_time                   datetime64[ns]
# cme_angle                         float64
# cme_width                         float64
# cme_speed                         float64
# initial_2nd_order                 float64
# final_2nd_order                   float64
# 20r_2nd_order                     float64
# cme_acceleration                  float64
# cme_mass                           object
# cme_kinetic_energy                 object
# cme_mpa                           float64
# cme_remarks                        object
# cme_quality                        object
# cme_halo                           object
# flare_end_time             datetime64[ns]
# flare_hg_longitude                 object
# flare_window_end           datetime64[ns]
# flare_hcx_position                 object
# flare_active_region_no             object
# flare_window_start         datetime64[ns]
# flare_string_latlon                object
# flare_start_time           datetime64[ns]
# flare_peak_time            datetime64[ns]
# flare_type                         object
# flare_hcy_position                 object
# flare_hg_latitude                  object
# flare_goes_class                   object
# srs_lon_extent                     object
# srs_no_spots                       object
# srs_carrington_lon                 object
# srs_active_region_no               object
# srs_observation_time       datetime64[ns]
# srs_hg_latitude                    object
# srs_mcintosh                       object
# srs_area                           object
# srs_hale                           object
# srs_hg_longitude                   object
# srs_string_latlon                  object
# smart_hcx_position                float64
# smart_flux_fraction               float64
# smart_limb_event                   object
# smart_hcy_position                float64
# smart_positive_flux                object
# smart_bipole_separation           float64
# smart_negative_flux                object
# smart_b_mean                      float64
# smart_wlsg                        float64
# smart_total_flux                   object
# smart_hg_latitude                 float64
# smart_positive_area               float64
# smart_psl_length                  float64
# smart_r_value                     float64
# smart_b_max                       float64
# smart_b_min                       float64
# smart_observation_time     datetime64[ns]
# smart_string_latlon                object
# smart_total_area                  float64
# smart_negative_area               float64
# smart_hg_longitude                float64
# dtype: object

# %%
# How many NaNs in the entire dataframe?
tot_count = df.isnull().sum().sum()
print('Dataframe NaN count: ' + str(tot_count))

# How many NaNs per column?
col_count = df.isnull().sum()
print('Column NaN count: \n' + str(col_count))
# Out:
# Dataframe NaN count: 979325
# Column NaN count:
# cme_time                       0
# cme_angle                    721
# cme_width                      0
# cme_speed                    103
# initial_2nd_order            468
# final_2nd_order              468
# 20r_2nd_order                468
# cme_acceleration             468
# cme_mass                   10549
# cme_kinetic_energy         10581
# cme_mpa                        0
# cme_remarks                    0
# cme_quality                    0
# cme_halo                       0
# flare_end_time             13676
# flare_hg_longitude         22184
# flare_window_end               0
# flare_hcx_position         24479
# flare_active_region_no     18115
# flare_window_start             0
# flare_string_latlon        24147
# flare_start_time           13676
# flare_peak_time            13681
# flare_type                 13676
# flare_hcy_position         24479
# flare_hg_latitude          22184
# flare_goes_class           19442
# srs_lon_extent             22843
# srs_no_spots               22843
# srs_carrington_lon         22843
# srs_active_region_no       22843
# srs_observation_time       22843
# srs_hg_latitude            22843
# srs_mcintosh               22843
# srs_area                   22843
# srs_hale                   22843
# srs_hg_longitude           22843
# srs_string_latlon          22843
# smart_hcx_position         23547
# smart_flux_fraction        23547
# smart_limb_event           23547
# smart_hcy_position         23547
# smart_positive_flux        23547
# smart_bipole_separation    23547
# smart_negative_flux        23547
# smart_b_mean               23547
# smart_wlsg                 23547
# smart_total_flux           23547
# smart_hg_latitude          23547
# smart_positive_area        23547
# smart_psl_length           23547
# smart_r_value              23547
# smart_b_max                23547
# smart_b_min                23547
# smart_observation_time     23547
# smart_string_latlon        23547
# smart_total_area           23547
# smart_negative_area        23547
# smart_hg_longitude         23547
# dtype: int64

# %%
# Simple way to count the number of unique values in a column
len(df["cme_time"].unique().tolist())
# Out:
# 29498

# %%
# Counting the values within a column 
halo_count = df['cme_halo'].value_counts()
print(halo_count)
print("")

# Notice it is not in order of halo class ---> reindex 
halo_count = halo_count.reindex(index = ['I','II','III','IV'])

# Converting this into a series
halo_series = pd.Series(halo_count, name='Frequency')
print(halo_series)

# Now converting this series into a dataframe
halo_df = halo_series.to_frame()
halo_df
# Out:
# I      27613
# II      1334
# IV       778
# III      503
# Name: cme_halo, dtype: int64
#
# I      27613
# II      1334
# III      503
# IV       778
# Name: Frequency, dtype: int64
#      Frequency
# I        27613
# II        1334
# III        503
# IV         778
